# %%
# Import dependencies

from bs4 import BeautifulSoup
from splinter import Browser
import requests
import re
import pandas as pd
from pprint import pprint
import pymongo

# %%
data = pd.read_csv(r"C:\Users\jimkn\Desktop\Number_of_trips_by_distanc.csv")

# %%
data.head()
# Out:
#        Days Stateid           County  Total Number of Trips  \
# 0  4/2/2019      OH  Guernsey County                 145455
# 1  4/2/2019      OH    Greene County                 543229
# 2  4/2/2019      OH    Geauga County                 312790
# 3  4/2/2019      OH    Gallia County                 122837
# 4  4/2/2019      OH    Fulton County                 144114
#
#    Number of Trips <1  Number of Trips 1-3  Number of Trips 3-5  \
# 0               32989                34489                21070
# 1              135011               128171                63296
# 2               68637                70492                32489
# 3               24805                26992                16869
# 4               30901                30350                13568
#
#    Number of Trips 5-10  Number of Trips 10-25  Number of Trips 25-50  \
# 0                 21032                  19008                   9577
# 1                 84830                  89309                  23443
# ...

# %%
data.drop(['Unnamed: 15', 
                'Unnamed: 16'], axis=1, inplace=True)

# %%
data.County = data.County.str.replace('County','')
data.head()
# Out:
#        Days Stateid     County  Total Number of Trips  Number of Trips <1  \
# 0  4/2/2019      OH  Guernsey                  145455               32989
# 1  4/2/2019      OH    Greene                  543229              135011
# 2  4/2/2019      OH    Geauga                  312790               68637
# 3  4/2/2019      OH    Gallia                  122837               24805
# 4  4/2/2019      OH    Fulton                  144114               30901
#
#    Number of Trips 1-3  Number of Trips 3-5  Number of Trips 5-10  \
# 0                34489                21070                 21032
# 1               128171                63296                 84830
# 2                70492                32489                 50814
# 3                26992                16869                 21742
# 4                30350                13568                 19809
#
#    Number of Trips 10-25  Number of Trips 25-50  Number of Trips 50-100  \
# ...

# %%
import sqlalchemy
# Connect to database 
engine = sqlalchemy.create_engine("postgresql://postgres:postgres@localhost/ETL Project")
con = engine.connect()

# %%
# Verify that there are no existing tables
print(engine.table_names())
# Out:
# ['covid_data', 'county_data']

# %%
table_name = 'trips'
data.to_sql(table_name, con)

# %%
print(engine.table_names())
# Out:
# ['covid_data', 'county_data', 'trips']

# %%
con.close()
